# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# Out:
# Running cells with 'Python 3.9.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/harsh/AppData/Local/Programs/Python/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
data=pd.read_csv('D:\Hacktoberfest\ML-Project\coin_Dogecoin.csv')

# %%
data.head()
# Out:
#    SNo      Name Symbol  ...     Close  Volume     Marketcap
# 0    1  Dogecoin   DOGE  ...  0.000205     0.0  1.509085e+06
# 1    2  Dogecoin   DOGE  ...  0.000269     0.0  2.169688e+06
# 2    3  Dogecoin   DOGE  ...  0.000362     0.0  3.188943e+06
# 3    4  Dogecoin   DOGE  ...  0.001162     0.0  1.115034e+07
# 4    5  Dogecoin   DOGE  ...  0.000704     0.0  7.284337e+06
#
# [5 rows x 10 columns]

# %%
data.tail()

# %%
data.head(10)
# Out:
#        SNo      Name Symbol  ...     Close        Volume     Marketcap
# 0        1  Dogecoin   DOGE  ...  0.000205  0.000000e+00  1.509085e+06
# 1        2  Dogecoin   DOGE  ...  0.000269  0.000000e+00  2.169688e+06
# 2        3  Dogecoin   DOGE  ...  0.000362  0.000000e+00  3.188943e+06
# 3        4  Dogecoin   DOGE  ...  0.001162  0.000000e+00  1.115034e+07
# 4        5  Dogecoin   DOGE  ...  0.000704  0.000000e+00  7.284337e+06
# ...    ...       ...    ...  ...       ...           ...           ...
# 2755  2756  Dogecoin   DOGE  ...  0.245264  1.321471e+09  3.194925e+10
# 2756  2757  Dogecoin   DOGE  ...  0.246411  9.170158e+08  3.210491e+10
# 2757  2758  Dogecoin   DOGE  ...  0.246483  9.735115e+08  3.211767e+10
# 2758  2759  Dogecoin   DOGE  ...  0.231614  1.267949e+09  3.018344e+10
# 2759  2760  Dogecoin   DOGE  ...  0.234422  1.265920e+09  3.055252e+10
#
# [2760 rows x 10 columns]

# %%
data['Dates'] = pd.to_datetime(data['Date']).dt.date
data['Time'] = pd.to_datetime(data['Date']).dt.time
data
# Out:
#        SNo      Name Symbol  ...     Marketcap       Dates      Time
# 0        1  Dogecoin   DOGE  ...  1.509085e+06  2013-12-16  23:59:59
# 1        2  Dogecoin   DOGE  ...  2.169688e+06  2013-12-17  23:59:59
# 2        3  Dogecoin   DOGE  ...  3.188943e+06  2013-12-18  23:59:59
# 3        4  Dogecoin   DOGE  ...  1.115034e+07  2013-12-19  23:59:59
# 4        5  Dogecoin   DOGE  ...  7.284337e+06  2013-12-20  23:59:59
# ...    ...       ...    ...  ...           ...         ...       ...
# 2755  2756  Dogecoin   DOGE  ...  3.194925e+10  2021-07-02  23:59:59
# 2756  2757  Dogecoin   DOGE  ...  3.210491e+10  2021-07-03  23:59:59
# 2757  2758  Dogecoin   DOGE  ...  3.211767e+10  2021-07-04  23:59:59
# 2758  2759  Dogecoin   DOGE  ...  3.018344e+10  2021-07-05  23:59:59
# 2759  2760  Dogecoin   DOGE  ...  3.055252e+10  2021-07-06  23:59:59
#
# [2760 rows x 12 columns]

# %%
data.columns=data.columns.str.lower()
data
# Out:
#        sno      name symbol  ...     marketcap       dates      time
# 0        1  Dogecoin   DOGE  ...  1.509085e+06  2013-12-16  23:59:59
# 1        2  Dogecoin   DOGE  ...  2.169688e+06  2013-12-17  23:59:59
# 2        3  Dogecoin   DOGE  ...  3.188943e+06  2013-12-18  23:59:59
# 3        4  Dogecoin   DOGE  ...  1.115034e+07  2013-12-19  23:59:59
# 4        5  Dogecoin   DOGE  ...  7.284337e+06  2013-12-20  23:59:59
# ...    ...       ...    ...  ...           ...         ...       ...
# 2755  2756  Dogecoin   DOGE  ...  3.194925e+10  2021-07-02  23:59:59
# 2756  2757  Dogecoin   DOGE  ...  3.210491e+10  2021-07-03  23:59:59
# 2757  2758  Dogecoin   DOGE  ...  3.211767e+10  2021-07-04  23:59:59
# 2758  2759  Dogecoin   DOGE  ...  3.018344e+10  2021-07-05  23:59:59
# 2759  2760  Dogecoin   DOGE  ...  3.055252e+10  2021-07-06  23:59:59
#
# [2760 rows x 12 columns]

# %%
data.corr()
# Out:
#                 sno      high       low  ...     close    volume  marketcap
# sno        1.000000  0.331338  0.339448  ...  0.335719  0.245079   0.335493
# high       0.331338  1.000000  0.983996  ...  0.993554  0.726273   0.993496
# low        0.339448  0.983996  1.000000  ...  0.993411  0.640496   0.993519
# open       0.334542  0.992309  0.991880  ...  0.989208  0.665606   0.989258
# close      0.335719  0.993554  0.993411  ...  1.000000  0.704855   0.999991
# volume     0.245079  0.726273  0.640496  ...  0.704855  1.000000   0.703837
# marketcap  0.335493  0.993496  0.993519  ...  0.999991  0.703837   1.000000
#
# [7 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2760 entries, 0 to 2759
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sno        2760 non-null   int64
#  1   name       2760 non-null   object
#  2   symbol     2760 non-null   object
#  3   date       2760 non-null   object
#  4   high       2760 non-null   float64
#  5   low        2760 non-null   float64
#  6   open       2760 non-null   float64
#  7   close      2760 non-null   float64
#  8   volume     2760 non-null   float64
#  9   marketcap  2760 non-null   float64
#  10  dates      2760 non-null   object
#  11  time       2760 non-null   object
# dtypes: float64(6), int64(1), object(5)
# memory usage: 258.9+ KB

# %%
data.isnull().sum()
# Out:
# sno          0
# name         0
# symbol       0
# date         0
# high         0
# low          0
# open         0
# close        0
# volume       0
# marketcap    0
# dates        0
# time         0
# dtype: int64

# %%
data=data.drop(['sno','symbol','date','time'],axis=1)

# %%
data
# Out:
#           name      high       low  ...        volume     marketcap       dates
# 0     Dogecoin  0.000866  0.000150  ...  0.000000e+00  1.509085e+06  2013-12-16
# 1     Dogecoin  0.000289  0.000116  ...  0.000000e+00  2.169688e+06  2013-12-17
# 2     Dogecoin  0.000362  0.000205  ...  0.000000e+00  3.188943e+06  2013-12-18
# 3     Dogecoin  0.001520  0.000328  ...  0.000000e+00  1.115034e+07  2013-12-19
# 4     Dogecoin  0.001143  0.000662  ...  0.000000e+00  7.284337e+06  2013-12-20
# ...        ...       ...       ...  ...           ...           ...         ...
# 2755  Dogecoin  0.247997  0.238848  ...  1.321471e+09  3.194925e+10  2021-07-02
# 2756  Dogecoin  0.250214  0.242454  ...  9.170158e+08  3.210491e+10  2021-07-03
# 2757  Dogecoin  0.252567  0.243425  ...  9.735115e+08  3.211767e+10  2021-07-04
# 2758  Dogecoin  0.246419  0.227838  ...  1.267949e+09  3.018344e+10  2021-07-05
# 2759  Dogecoin  0.241910  0.229842  ...  1.265920e+09  3.055252e+10  2021-07-06
#
# ...

# %%
data.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f345c974410>,
# ...
#       dtype=object)

# %%
data = data.drop_duplicates(subset=['high','low'])
data
# Out:
#           name      high       low  ...        volume     marketcap       dates
# 0     Dogecoin  0.000866  0.000150  ...  0.000000e+00  1.509085e+06  2013-12-16
# 1     Dogecoin  0.000289  0.000116  ...  0.000000e+00  2.169688e+06  2013-12-17
# 2     Dogecoin  0.000362  0.000205  ...  0.000000e+00  3.188943e+06  2013-12-18
# 3     Dogecoin  0.001520  0.000328  ...  0.000000e+00  1.115034e+07  2013-12-19
# 4     Dogecoin  0.001143  0.000662  ...  0.000000e+00  7.284337e+06  2013-12-20
# ...        ...       ...       ...  ...           ...           ...         ...
# 2755  Dogecoin  0.247997  0.238848  ...  1.321471e+09  3.194925e+10  2021-07-02
# 2756  Dogecoin  0.250214  0.242454  ...  9.170158e+08  3.210491e+10  2021-07-03
# 2757  Dogecoin  0.252567  0.243425  ...  9.735115e+08  3.211767e+10  2021-07-04
# 2758  Dogecoin  0.246419  0.227838  ...  1.267949e+09  3.018344e+10  2021-07-05
# 2759  Dogecoin  0.241910  0.229842  ...  1.265920e+09  3.055252e+10  2021-07-06
#
# ...

# %%
data.boxplot(column="high")

# %%
data=data[data["high"]>0.4]

# %%
x=pd.DataFrame(data,columns=['high','low'])
x
# Out:
#           high       low
# 2678  0.437700  0.180488
# 2681  0.431751  0.309080
# 2682  0.422347  0.271618
# 2694  0.400029  0.364874
# 2695  0.445567  0.373631
# 2696  0.605998  0.400800
# 2697  0.695262  0.523822
# 2698  0.663616  0.545102
# 2699  0.731972  0.520174
# 2700  0.737567  0.608168
# 2701  0.697625  0.425706
# 2702  0.569687  0.421291
# 2703  0.546651  0.445034
# 2704  0.519975  0.385376
# 2705  0.519461  0.357175
# 2706  0.589690  0.464622
# 2707  0.562676  0.491299
# 2708  0.548145  0.451023
# 2709  0.515221  0.458551
# 2710  0.515599  0.470384
# 2711  0.684735  0.218267
# 2712  0.433192  0.296253
# 2713  0.411975  0.314766
# 2725  0.444590  0.352588
# 2726  0.440763  0.378819
# 2727  0.400982  0.351442

# %%
y=pd.DataFrame(data,columns=['marketcap'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)
print(y_test)
# Out:
#          marketcap
# 2700  8.242978e+10
# 2713  4.660975e+10
# 2704  4.993290e+10
# 2702  5.829061e+10
# 2696  7.008193e+10
# 2710  6.172964e+10
# 2725  5.497691e+10
# 2712  5.189730e+10

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=regressor.predict(x_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test),1))
# Out:
# [[8.98e+10 8.24e+10]
#  [4.82e+10 4.66e+10]
#  [5.97e+10 4.99e+10]
#  [6.53e+10 5.83e+10]
#  [6.53e+10 7.01e+10]
#  [6.68e+10 6.17e+10]
#  [5.31e+10 5.50e+10]
#  [4.77e+10 5.19e+10]]

# %%
from sklearn.metrics import r2_score
print(r2_score(y_pred,y_test))
# Out:
# 0.791020635037468
